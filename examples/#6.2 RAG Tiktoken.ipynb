# %%
# https://platform.openai.com/tokenizer

from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter

# %%
file_path = "../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf"

# %%
splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=200,
    chunk_overlap=50,
    length_function=len,
)
loader = UnstructuredFileLoader(file_path)
loader.load_and_split(text_splitter=splitter)
# Out:
# [Document(page_content='[MEPC 80 결과보고서, 2023.7.10.]\nMEPC 80차 결과보고\n한국해운협회 해무팀\n해양환경보호위원회(MEPC) 80차 개요\n1. 일반사항\n회의명 : 제80차 해양환경보호위원회(MEPC 80)\n기 간 : 2023. 07. 03. ~ 07. 07. (5일간)\n장 소 : 영국 런던 IMO 본부\n참 석 : 해양수산부 등 대표단 34명\n주요논의 주제', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='장 소 : 영국 런던 IMO 본부\n참 석 : 해양수산부 등 대표단 34명\n주요논의 주제\n⦁평형수내 유해생물(BWM)\n⦁대기오염, 선박 에너지효율(EEDI)\n⦁선박으로부터의 GHG 배출 감축(초기전략 개정, 중기조치 초안)\n⦁선박 배출 해양플라스틱 조치계획 개발\n⦁특별해역, 배출통제해역 및 특별민감해역의 식별 등 16개 의제', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='⦁특별해역, 배출통제해역 및 특별민감해역의 식별 등 16개 의제\n2. MEPC 80차 주요 결정 사항\n2030~2050 감축목표(Level of Ambition)\n⦁2050년 경(By or around 2050) 국제해운 탄소중립 실현\n⦁2030년까지 저·무탄소 연료 및 기술 5~10% 사용\n중간 지표(indicative checkpoint) 설정', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='중간 지표(indicative checkpoint) 설정\n⦁2050년 탄소중립 실현을 위해, 2008년 온실가스 총 배출량 대비 2030\n년까지 20~30%, 2040년까지 70~80% 감축 노력\n중기 조치(Mid-term measure)\n⦁연료유 표준제(GFS, Goal based Fuel Standard)와 온실가스 감축 수', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='⦁연료유 표준제(GFS, Goal based Fuel Standard)와 온실가스 감축 수\n준에 따라 일정 부담금을 부과하는 결합조치 도입에 합의\n⦁해운산업 및 국가별 영향 등을 분석하기 위한 영향평가 착수, 구체 이행\n방안 논의 후 2027년 5월 시행 예정\n[의제별 논의 경과 및 진행사항]\n1. IMO 온실가스 감축 초기전략의 개정', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='[의제별 논의 경과 및 진행사항]\n1. IMO 온실가스 감축 초기전략의 개정\n국제해운 규제기관인 IMO 에서는 2018년 IMO 온실가스 감축 초기전략 채택\n시 국제해운에서 발생하는 연간 총 온실가스 배출량을 2008년 대비 2050년까\n지 절반으로 감축하겠다는 의욕수준을 설정한 바 있다. 이번 MEPC 80차에서', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='지 절반으로 감축하겠다는 의욕수준을 설정한 바 있다. 이번 MEPC 80차에서\n강화된 IMO 온실가스 감축 초기전략이 논의 및 채택되었다.\nMEPC 77차 이후 MEPC 80차 채택을 목표로 초기전략 개정 작업을 개시하였\n고, 회의 참여국들은 지구 온난화의 심각성 인식 등으로 초기전략 목표 강화\n필요성에 대한 전반적인 공감대를 형성하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='필요성에 대한 전반적인 공감대를 형성하였다.\n2050년 초기전략 의욕수준에 대하여 대부분의 대표단들은 국제해운의 온실가\n스 배출이 가능한 빨리 정점에 도달하고, 2050년까지 그 배출을 없게 하는 것\n에 모두 동의하였다. 다만, 2030년과 2040년의 감축목표 설정에 있어 여러 의', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='에 모두 동의하였다. 다만, 2030년과 2040년의 감축목표 설정에 있어 여러 의\n견이 제시되었고 작업반(WG)을 MEPC 80차 회기중 개설하여 상세 논의를 진\n행하였다.\n작업반 논의전 온실가스 감축 초기전략에 대하여 MEPC 80 개최전 회기간 작\n업반 회의(ISWG-GHG 15, 6.26~6.30)에서 개정안에 대한 논의가 진행되었다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='업반 회의(ISWG-GHG 15, 6.26~6.30)에서 개정안에 대한 논의가 진행되었다.\n2050년 목표에 대해 회원국들은 Net-zero, Phase-out, zero emission 등\n다양한 표현을 사용하여 배출량 0를 달성해야 함을 주장하였으며, 이 중\nUNFCCC에서 이미 사용하고 있는 용어인 Net-zero의 선호를 확인하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='UNFCCC에서 이미 사용하고 있는 용어인 Net-zero의 선호를 확인하였다.\n목표연도에 대해 “Mid-century”와 “at least before 2050”으로 의견이 양분\n되었다. “Mid-century”의 주장 근거는 글래스고 기후 합의 문구 내용에 포함\n되었음을 근거로 하였으며, 지지 국가는 중국, 브라질, 아르헨티나, 남아공, 우', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='되었음을 근거로 하였으며, 지지 국가는 중국, 브라질, 아르헨티나, 남아공, 우\n르과이, 사우디아라비아, 벨라루스, 러시아, 쿠바, 파라과이, 인도네시아, 페루,\n베네수엘라, 에콰도르 등이 지지하였다.\n글래스고 기후 합의문 문구 : The main goal was to secure global net', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='zero by mid-century and keep a maximum of 1.5 C degrees of\nwarming within reach.\n“at least before 2050”을 지지하는 근거는 IPCC AR 61) 보고서 문구를 인용\n한 것으로써 지지국가는 우리나라, EU, 미국, 영국, 캐나다, 노르웨이, 군소도', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='한 것으로써 지지국가는 우리나라, EU, 미국, 영국, 캐나다, 노르웨이, 군소도\n서국, 일본, 파나마, 싱가폴, 몰디브, 호주, 나미비아 등이다.\n중간목표 설정에 대하여 2050년 탈탄소화 목표 달성을 위해 2030년(감축량,\n연료/에너지 사용률), 2040년 중간목표의 필요성을 지지하는 국가와 현재 단\n계에서 불필요하다는 주장을 하는 국가로 구분되었다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='계에서 불필요하다는 주장을 하는 국가로 구분되었다.\n반면, 중국 등 개도국을 중심으로 중간목표 설정에 반대하였으나, 국제해운 에\n너지(Zero 또는 Near-zero) 목표에 대해서는 일부 국가(인도, UAE)에서 지지\n의사를 표시하였다.\n논의 결과 초기전략 개정초안을 최종보고서 내용에 포함하여 MEPC 80차로\n제출하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='논의 결과 초기전략 개정초안을 최종보고서 내용에 포함하여 MEPC 80차로\n제출하였다.\n이에 대해 MEPC 80차에서는 ISWG-GHG 14차 및 15차 결과에 대한 회원국\n들의 의견을 수렴하였고, 대부분의 회원국들은 기후위기의 심각성을 고려하여\n이번 MEPC 80차에서 2023 초기전략 개정안을 채택해야하며, 공정하고 정의', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이번 MEPC 80차에서 2023 초기전략 개정안을 채택해야하며, 공정하고 정의\n로운 전환을 보장할 것에는 전반적인 동의를 확인하였으나, 구체적인 사항에\n대해서는 개도국 및 선진국 간의 의견이 양분되었다.\n선진국 및 군소도서국에서는 IMO의 감축목표는 파리협약의 온도 목표(1.5도)', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='선진국 및 군소도서국에서는 IMO의 감축목표는 파리협약의 온도 목표(1.5도)\n와 일치하여야 하며 이를 위하여 2030년 2040년 Indicative checkpoint 및\n2050년 넷제로를 의욕수준으로 결정할 것을 주장하였다. 중기조치에 있어 경\n제적 요소와 기술적 요소를 결합한 조치가 중기조치로써 고려되어야 하고, 중', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='제적 요소와 기술적 요소를 결합한 조치가 중기조치로써 고려되어야 하고, 중\n기조치를 2025년에 채택하기 위하여 MEPC 80차에서 종합영향평가를 착수할\n것을 제안하였다. 특히, 군소도서국의 경우 경제적 요소로서 Universial Levy\n가 도입되어야 함을 특별히 강조하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='가 도입되어야 함을 특별히 강조하였다.\n1) IPCC Sixth Assessment Report : 기후 변화에 관한 유엔 정부 간 패널의 여섯 번째 평가 보고서는 기후 변화에 관한 과학적, 기술적, 사회 경제적 정보를 평가 하는 일련의 보고서\n개도국은 국제해운이 전 세계 무역의 80%를 차지하므로 해운에서의 잘못된', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='개도국은 국제해운이 전 세계 무역의 80%를 차지하므로 해운에서의 잘못된\n시그널은 전 세계에 무역의 혼란으로 식량, 에너지 문제를 일으킬 수 있다는\n점을 강조하였다. 이에 따라 실현 가능하며 현실적인 목표로 2050년 목표를\n“net zero by or around mid-of century”로 설정할 것을 주장하였다. 중기', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='조치에 있어서 Levy는 무역가격을 상승시켜 개도국에 식량 및 에너지 문제를\n초래할 수 있으므로 적절한 중기조치가 아님을 주장하였다.\n논의결과 초기전략은 기존의 2050년까지 2008년 총 온실가스 배출량 대비\n50% 감축하기로 한 기존 목표를 상향하여 2030년까지 20~30%를, 2040년까', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='50% 감축하기로 한 기존 목표를 상향하여 2030년까지 20~30%를, 2040년까\n지 70~80%를 감축하고 2050년경(By or around 2050)에는 순 배출량 제로\n(Net-Zero)를 달성하는 것을 목표로 설정하였다.\n다만, 2030~2040년 감축량의 경우 각 국가의 자율적 감축 노력을 촉진하기', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='다만, 2030~2040년 감축량의 경우 각 국가의 자율적 감축 노력을 촉진하기\n위한 목적으로 의무적 달성 목표라기보다는 점검 차원의 지표로써 작용한다는\n점에서 2050년 목표와 차이점을 가지고 있다.\n또한 2030년까지 저·무탄소 연료 및 기술을 5~10% 사용하도록 노력함에 동의\n하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='또한 2030년까지 저·무탄소 연료 및 기술을 5~10% 사용하도록 노력함에 동의\n하였다.\n온실가스 감축과 관련한 CCS(탄소포집)에 대한 논의로써 대한민국 제출문서2)\n관련하여 의견조회를 통해 MEPC 80차 후 개설될 ISWG-GHG 16차에 포함하\n여 논의할 것을 제안하였다. 우리나라 등은 OCCS 기술의 감축잠재력 및 산업', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='여 논의할 것을 제안하였다. 우리나라 등은 OCCS 기술의 감축잠재력 및 산업\n계의 많은 관심을 고려하여 빠른 논의 착수를 주장하며 의장이 제안한\nISWG-GHG 16에 포함할 것을 찬성(노르웨이, 라이베리아, 일본, 중국, 쿡아일\n랜드, 영국, CESA)하였다.\n스페인 등(미국, 독일, 네덜란드, 터키, 솔로몬제도)은 현재 시점에서 작업 계', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='스페인 등(미국, 독일, 네덜란드, 터키, 솔로몬제도)은 현재 시점에서 작업 계\n획 설정 구성은 시기상조이고, LCA 가이드라인 측면에서 함께 고려가 필요함\n을 주장하였다.\n논의 결과 ISWG-GHG 16차에서 OCCS(선상탄소포집) 논의를 착수하기로 합\n의하였으며, 안전성 확보를 위하여 MSC 등 연관 위원회에 검토를 요청하기로\n하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content="의하였으며, 안전성 확보를 위하여 MSC 등 연관 위원회에 검토를 요청하기로\n하였다.\n2) MEPC 80/7/7 The use of onboard carbon capture systems within IMO's regulatory framework\n온실가스 초기전략 설정에 대해, 2050년 Net-Zero 달성을 위한 보고서 등에", metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='온실가스 초기전략 설정에 대해, 2050년 Net-Zero 달성을 위한 보고서 등에\n따르면 2030년 2008년 대비 약 50%감축, 2040년 약 70%의 감축이 필요한\n것으로 확인된다. 현재 설정된 2030년 목표 20~30%, 2040년 70~80% 감축\n목표는 2040년도 목표는 Net-Zero 경로에 부합하지만 2030년 목표는 경로에', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='목표는 2040년도 목표는 Net-Zero 경로에 부합하지만 2030년 목표는 경로에\n부합하지 않는 상황이며, 이는 기술, 인프라 등의 보급 확산이 지수함수적 성\n격을 가지고 있기 때문인 것으로 파악된다.\n현재 선사들이 직면하고 있는 CII 규제는 2026년 리뷰 후 감축 경로에 맞춰', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='현재 선사들이 직면하고 있는 CII 규제는 2026년 리뷰 후 감축 경로에 맞춰\n연간 감축률이 상향될 것으로 예상된다. 이는 2050년 감축목표가 50%에서\n0%(Net-Zero)로 상향됨에 따라 어떠한 경로가 설정되더라도 현행 연간 2%\n감축보다 상향될 수 밖에 없는 상황인 것으로 확인된다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='감축보다 상향될 수 밖에 없는 상황인 것으로 확인된다.\n이에 따라, 2030년 20% 감축 수준을 달성하기 위해 바이오연료 적용 및 선박\n운항최적화, 그리고 선박 에너지효율향상장치(ESD) 적용 등을 진행하고 일부\n선대의 무·저탄소 선박 전환이 필요할 것으로 예상된다. 2040년의 70% 감축', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='선대의 무·저탄소 선박 전환이 필요할 것으로 예상된다. 2040년의 70% 감축\n목표 달성을 위해선 무·저탄소 선박이 전체선대의 절반 이상의 비중을 차지해\n야할 것으로 예상되는 상황이다. 2030년 감축목표가 IMO 보고서 등에서 논하\n고 있는 45% 이하로 설정되어 이를 보완하기 위해 2030년 새롭게 저·무탄소', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='고 있는 45% 이하로 설정되어 이를 보완하기 위해 2030년 새롭게 저·무탄소\n연료 및 기술 5% 사용을 목표로 추가한 것으로 사료된다.\n전과정(WtW) 기준의 무탄소 연료의 조기 도입을 위한 산업계 협력을 통해 인\n프라 및 기술의 조기 확보 추진이 필요한 상황이며, 이번에 새롭게 추가된 저·', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='프라 및 기술의 조기 확보 추진이 필요한 상황이며, 이번에 새롭게 추가된 저·\n무탄소 연료의 2030년까지 5%~10% 사용에 따른 논의경과에 대한 확인이 필\n요한 상황이다.\n2. 중기후보조치 선정 및 검토\nMEPC 80차에서 논의를 위해 사전 제안된 중기후보조치는 크게 다섯가지로\n분류될 수 있다.\n1) 무배출 선박 인센티브(ZESIS3)) 제도 (일본)', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='분류될 수 있다.\n1) 무배출 선박 인센티브(ZESIS3)) 제도 (일본)\n일본에서 제안한 무배출 선박 인센티브(ZESIS) 제도로 전과정 온실가스 배출\n선박에 기여금을 부과하고, 저/무배출 연료를 사용하는 선박에 인센티브를 부\n여하는 “Feebate Mechanism”과 기존 GFS를 결합시킨 형태의 제도이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='여하는 “Feebate Mechanism”과 기존 GFS를 결합시킨 형태의 제도이다.\nGFS 기준을 미달성한 선박은 달성한 선박으로부터 SRU(Surplus Reward\nUnit) 또는 RU(Remedial Unit)를 구입하여 부족분을 충당함으로써 규제를 이\n행할 수 있고, 무탄소 연료를 선도입한 선행자(First Mover)는 배출권 판매', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='행할 수 있고, 무탄소 연료를 선도입한 선행자(First Mover)는 배출권 판매\n등을 통해 인센티브 수혜를 받을 수 있게 된다. 그러나 SRU의 경우 배출권\n거래제의 ‘배출권’과 유사하게 초과 달성한 선박에 지급되는 보상개념으로 판\n매/구입 가격은 시장에서 결정되게 되어 가격 불확실성 등 선사 부담이 커질', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='매/구입 가격은 시장에서 결정되게 되어 가격 불확실성 등 선사 부담이 커질\n것으로 예상되는 상황이다. 이에 대비하여 RU는 IMO에서 결정한 고정가격으\n로 ‘배출권’을 구매하는 개념으로 현재 논의되고 해운업계에서 선호하고 있는\n가격 확정을 통한 예측이 가능한 탄소세(Levy) 개념과 유사하여 해운업계 입', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='가격 확정을 통한 예측이 가능한 탄소세(Levy) 개념과 유사하여 해운업계 입\n장을 고려하여 협회에서는 SRU 보다는 RU로의 도입을 요청하였고, 우리나라\n는 산업계 의견을 반영하여 지속적으로 RU로 의견을 개진하고 있다.\n2) 연료유 표준제도(GFS) 및 온실가스 부담금(GHG Levy)제도의 결합 (EU)', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='2) 연료유 표준제도(GFS) 및 온실가스 부담금(GHG Levy)제도의 결합 (EU)\nEU에서 제안한 GFS+GHG Levy 결합제도는 규제 미준수 선박의 갑작스런 운\n항불가 사항으로 야기되는 국제물류 혼란을 방지하고자 배출권 구매 또는 벌\n금제도 등을 통해 규제를 달성하고 운항할 수 있도록 규제 이행의 유연성을', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='금제도 등을 통해 규제를 달성하고 운항할 수 있도록 규제 이행의 유연성을\n주는 체계인 유연성 메커니즘을 포함하는 GFS 제도와 전과정 온실가스 배출\n선박에 기여금을 부과하는 GHG Levy를 결합한 형태의 제도를 제안하고 있다.\n3) 국제해사지속가능성 연료 및 기금 메커니즘(IMSF&F) (중국)', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='3) 국제해사지속가능성 연료 및 기금 메커니즘(IMSF&F) (중국)\nIMSF&F(International Maritime Sustainability Fuels and Fund)는 기존\n중국이 아르헨티나, 브라질 등과 함께 제안한\nIMSF&R(International', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='중국이 아르헨티나, 브라질 등과 함께 제안한\nIMSF&R(International\nMaritime Sustainability Funding and Reward)을 보완한 제안으로 타국가\n에서 제안된 조치들을 포함하고 있다. 주요 차이점으로는 기존 IMSF&R의 경\n우 기준점 설정을 위해 탄소집약도지표(CII)를 활용하였으나, 대체연료 및 혁신', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='우 기준점 설정을 위해 탄소집약도지표(CII)를 활용하였으나, 대체연료 및 혁신\n기술을 촉진할 수 있는 지표 사용을 위해 GFI(GHG Fuel Intensity, 연료에너\n지의 GHG 집약도)로 대체하였다.\n이를 통해, 온실가스 이중계산을 방지하기 위해 각 국가별 온실가스 인벤토리', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이를 통해, 온실가스 이중계산을 방지하기 위해 각 국가별 온실가스 인벤토리\n3) ZESIS : Zero-Emission Shipping Incentive Scheme\n에 포함되는 연료의 제품 생산 및 운송-유통 단계의 온실가스 배출량은 선박\n에서의 배출량으로 포함하지 않아 TtW 기반 온실가스 집약도를 제한하고 기', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='에서의 배출량으로 포함하지 않아 TtW 기반 온실가스 집약도를 제한하고 기\n준보다 초과 달성한 선박에 SRU를 지급하고 이를 미달성 선박에 판매하여 수\n익 창출이 가능한 구조이다. 또한, LCA 가이드라인에서 인정하는 지속가능연\n료를 사용했을 경우에만 SRU를 부여하도록 하여 WtW기반의 저배출량 연료\n사용을 유도하는 구조를 갖추고 있다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='사용을 유도하는 구조를 갖추고 있다.\n4) 온실가스 연료유 표준제도의 단순화 제안 (ICS)\nEU에서 제안한 GFS의 이행절차 복잡성으로 인해 실현가능한 감축률(2030년\n까지 5%)을 설정하고 제도를 단순화시킬 것을 제안하였다. EU의 GFS는 규제\n미달성시 유연성 메커니즘을 통해 규제를 이행할 수 있으나, 이러한 제도가 오', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='미달성시 유연성 메커니즘을 통해 규제를 이행할 수 있으나, 이러한 제도가 오\n히려 복잡성을 초래하는 점을 지적하였다.\n또한, 선박 저유황유 도입과 유사하게 선박이 부득이한 사정(항구 인프라 부족\n등)으로 대체연료의 수급이 불가할 경우 기국 허가를 통해 사용유예 가능 조항', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='등)으로 대체연료의 수급이 불가할 경우 기국 허가를 통해 사용유예 가능 조항\n(FONAR, Fuel Oil Non Availability Report) 신설을 제안하였다.\n5) 국제해사기구 해사 지속가능성 기금 및 보상 메커니즘 (ICS)\nIMSF&R 메커니즘에 대하여 ICS에서는 CO2톤당 부담금을 징수하여 기금을 마', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='IMSF&R 메커니즘에 대하여 ICS에서는 CO2톤당 부담금을 징수하여 기금을 마\n련하고, 이를 대체연료 사용선박에 대한 보상금과 개도국 지원, R&D 등에 활\n용할 것을 제안하였다. 이중 적어도 5% 이상의 대체연료 사용선박에 보상금을\n제공할 수 있도록 하였으며, 기여 보상금 수준을 5년마다 수정 검토한다는 내\n용을 담고 있다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='용을 담고 있다.\n이에 대하여 ISWG-GHG 15차에서는 중기조치 논의에 있어서 다음의 7가지\n논의사항에 대한 회원국 의견을 요청하였다.\n① 기술적 요소와 관련하여, GFS를 추가 개발하는 것으로 의견이 수렴되었음\n에 주목하여, 작업반은 목표기반 및 선박 탄소집약도의 단계적 감소를 의\n무화하는 에너지 표준을 추가 개발할 것을 권고하는 단계인지?', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='무화하는 에너지 표준을 추가 개발할 것을 권고하는 단계인지?\n② 경제적 요소와 관련하여, 다양한 제안에 대한 공통 요소가 증가하였으나 다\n양한 입장도 식별되었음에 주목하여 작업반은 1) 경제적 요소로써의 단일\n제안(Levy, feebate, reward, ECTS 등)을 권고하거나 2) 현 단계에서의', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='유연성을 유지할 필요성을 인지하여, 회원국 영향, 기금 조성, 관리, 분배\n등에 주목하여 3단계에서 추가 평가 및 정교화를 권고하는 단계인지?\n③ 어떠한 중요한 요소 또는 공통점이 3단계에서 고려되어야 하는지(LCA 고\n려 방안, 부정적 영향 해소 등)?\n④ 작업반이 단일, 결합조치 또는 개별적 요소의 개발을 권고하는 단계인지?', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='④ 작업반이 단일, 결합조치 또는 개별적 요소의 개발을 권고하는 단계인지?\n⑤ MEPC 80에서 결합조치의 종합 영향 평가를 시작할 것을 권고하는데 동의\n하는지?\n⑥ 중기조치의 완료, 채택, 발효일에 대한 목표 일정이 어떻게 되는지?\n⑦ 추가 개발되어야 하는 기술적 및 경제적 요소와 결합 조치의 어떠한 부분\n이 개정 전략의 섹션 4에 포함되어야 하는지?', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이 개정 전략의 섹션 4에 포함되어야 하는지?\n다수 회원국이 위 질문에 대한 각각의 의견을 표명하기 보다는 선호하는 기술\n적 및 경제적 조치, 중기조치 도입 일정 및 종합 영향평가 관련 의견 위주로\n의견을 제시하였다.\n대한민국, EU, 군소도서국은 기술적 요소로써 GFS와 경제적 요소로써 Levy를', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content="대한민국, EU, 군소도서국은 기술적 요소로써 GFS와 경제적 요소로써 Levy를\n결합한 결합조치 도입을 주장하였다. 또한, 국가별 준비 수준이 상이하므로\nGFS에 대한 유연성 메커니즘이 도입되어야 한다는 주장이다. 중기조치는\nWtW 기반이어야 하며, MEPC 80에서 3단계 논의를 시작하여 '25년에 채택", metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content="WtW 기반이어야 하며, MEPC 80에서 3단계 논의를 시작하여 '25년에 채택\n및 '27년 발효를 목표로 해야한다는 의견을 밝혔다.\n개도국 등4)은 중국에서 제안한 IMSF&F이 기술적 및 경제적 요소를 결합한\n조치로써 이를 지지하였다. Levy는 시장과의 거리가 있는 일부 회원국에게 관", metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='조치로써 이를 지지하였다. Levy는 시장과의 거리가 있는 일부 회원국에게 관\n련 비용을 전가함으로써 국가간 격차를 야기할 뿐만 아니라, Levy는 신규 체\n제로써 규제 이행 준비에 있어서 행정적 부담이 발생하며, 배출량 감축이 목표\n가 아닌 기금 조성을 위한 조치이므로 Levy 도입에 반대하였다. 이에 대하여', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='가 아닌 기금 조성을 위한 조치이므로 Levy 도입에 반대하였다. 이에 대하여\n경제적 요소에 따른 수익은 해운분야에만 분배되어야 한다는 점을 강조했다.\n(타 분야로의 수익 분배 반대) 또한, 조치 채택 전 종합영향평가가 반드시 완\n료되어야 하며, 구체적인 시기를 언급하진 않았으나 단기조치 도입시 식별된', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='료되어야 하며, 구체적인 시기를 언급하진 않았으나 단기조치 도입시 식별된\n문제사항들을 상기하여 이미 합의된 절차에 따라서 이행해야 한다는 의견을\n피력했다.\n4) 중국, 아르헨티나, 브라질, 페루, 칠레, 우루과이, 남아프리카, 쿠바, 과테말 라, 에콰도르, 베네수엘라, 파라과이, 사우디아라비아, 대만, 방글라데시, 벨 라루스, 북한, 러시아 등', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='선진국 등5)은 GFS + 경제적 조치를 결합한 결합조치를 지지하며, 경제적 조\n치로써 어떠한 조치(levy, feebate, flat rate)를 고려할지와 GFS와 어떻게 결\n합할 것인지에 대해서는 3단계에서 추가로 논의할 것을 주장하였다.\n호주는 결합조치를 지지하며 기술적 요소의 GFS와\nIMSF&F는 유사하나', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='호주는 결합조치를 지지하며 기술적 요소의 GFS와\nIMSF&F는 유사하나\nIMSF&F가 간략하므로 이를 지지하며, 영국에서 제안한 종합영향평가 제안을\n지지하였다.\n노르웨이는 기술적 요소로써 GFS 도입을 지지하며, 경제적 요소로써 일본의\nZESIS 제안이 적절한 것으로 보이나 현재 단계에서 이를 결정하기 보다는 3\n단계에서 추가 논의할 것을 주장하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='단계에서 추가 논의할 것을 주장하였다.\n이와 관련하여 우리나라는 제안된 조치에 대한 평가 결과 온실가스 연료유 표\n준제도(GFS)와 온실가스 부담금제도(Levy)가 최적 제안임을 산업계 의견을 반\n영하여 우리나라 훈령으로 확정하였다. 또한 중기조치 논의에 따른 유연성 메\n커니즘 고려시 배출권 거래제 개념을 담고 있는 SRU가 아닌 고정 가격을 지', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='커니즘 고려시 배출권 거래제 개념을 담고 있는 SRU가 아닌 고정 가격을 지\n불하는 탄소세 개념인 RU를 적용할 것을 지속적으로 요청하여 우리나라 훈령\n에 반영되었다.\n이와 관련 각 회원국들은 목표 달성을 위해 연료별 온실가스 집약도를 단계적\n으로 제한하는 연료유 표준제(GFS, goal based Fuel Standard)와 온실가스', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='감축 수준에 따라 일정 비용을 부과하는 규제(경제적 규제)가 결합된 결합조치\n(Basket Measure)를 도입하기로 합의하였다.\n결합조치는 기술적 요소와 경제적 요소를 함께 고려하는 결합된 조치로써 규\n제 도입으로 인해 국가, 해운산업 등에 미칠 수 있는 영향 분석이 완료되고 규', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='제 도입으로 인해 국가, 해운산업 등에 미칠 수 있는 영향 분석이 완료되고 규\n제 수준·대상 등에 대한 구체적인 기준과 이행방안이 마련된 후 2027년에 시\n행될 예정이다.\n5) 영국, 미국, 캐나다, 싱가포르, 뉴질랜드등\n<향후 중기조치 개발 계획>\n시기\n종합영향평가*\n중기조치 개발\nMEPC 80(‘23.7)\n종합영향평가 착수\n중기조치 개발 착수', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='중기조치 개발\nMEPC 80(‘23.7)\n종합영향평가 착수\n중기조치 개발 착수\nMEPC 81(‘24.4)\n중간보고서 제출\n결합조치 이행 방안 마련\nMEPC 82(‘24.10)\n최종보고서 제출\nMEPC 83(‘25.4)\n조치 승인\nMEPC 83 – 84\n사이(‘25.10)\n조치 채택\nMEPC 84(‘26, 봄)\nMEPC 85(‘26, 가을)\n‘27.5', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='조치 채택\nMEPC 84(‘26, 봄)\nMEPC 85(‘26, 가을)\n‘27.5\n조치 시행\n3. LCA 지침서 최종보고서 검토\nIMO에서는 연료의 생산부터 사용단계까지의 온실가스 배출량 평가 지침 마련\n을 위한 회기간 실무작업반을 ‘22.3~’23.7 까지 운영한 바 있으며 그에 따른', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='을 위한 회기간 실무작업반을 ‘22.3~’23.7 까지 운영한 바 있으며 그에 따른\n최종보고서를 ISWG-GHG 15차에 제출했고, MEPC 80차에서 채택되었다.\n향후 작업방향에 대한 방법론적 요소에 대한 추가 작업 필요사항을 식별하였\n으며, 특히 직접토지이용변화 및 CCS 등과 같은 산정 방법론에 대한 개선 및', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='으며, 특히 직접토지이용변화 및 CCS 등과 같은 산정 방법론에 대한 개선 및\n개발 측면에서의 추가적인 기술 작업 필요성이 식별되었다.\n이에 따라, LCA 지침서 회기간 실무작업반에서 추가적인 지침서에 대한 개발\n특히, 연료의 지속가능성 및 제3자 검정-인증 관련 지침서 개발의 필요성이', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='특히, 연료의 지속가능성 및 제3자 검정-인증 관련 지침서 개발의 필요성이\n확인되었고 유럽에서 전문가 워크숍(MEPC 81차 전 개최)이 제안되었다.\n또한, 새로운 기술의 발전과 과학적 지식이 지침서에 반영될 수 있도록 LCA\n지침에 대한 지속적인 과학적 검토가 필요하다는 추가 작업사항이 확인되어', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='지침에 대한 지속적인 과학적 검토가 필요하다는 추가 작업사항이 확인되어\nISWG-GHG 16차를 통해 MEPC 81차에 기본 배출계수 등이 포함되는 서면\n보고서를 제출할 예정이다.\n이러한 WtW로 평가된 연료 적용 및 효과를 보기 위해서는 2027년 도입예정\n인 GFS+Levy의 적용이 필요하며, 연료 공급지역 및 항로별 취항선사 적용을', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='인 GFS+Levy의 적용이 필요하며, 연료 공급지역 및 항로별 취항선사 적용을\n위한 유불리 사항 파악 및 케이스별 대처가 필요한 상황이다.\n4. 바이오연료 사용 임시지침 승인\n지속 가능한 바이오연료를 현행 IMO 규제(DCS, CII 등)에 조기 적용할 수 있\n도록 CO2 배출계수를 ‘0’으로 산정할 것을 제안하는 결의서가 인도에 의해 제', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='도록 CO2 배출계수를 ‘0’으로 산정할 것을 제안하는 결의서가 인도에 의해 제\n안되었다. 이에 대해 LCA 지침서 추가개발까지의 시간이 추가적으로 필요하고\n규제의 불확실성에 대한 조기 해소에 필요한 조치로 확인되어 산업계의 필요\n성을 정부대표단에 전달한 바 있으며 이를 반영하여 우리나라는 찬성 의견을', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='성을 정부대표단에 전달한 바 있으며 이를 반영하여 우리나라는 찬성 의견을\n개진하였다. 그러나 미국 등 바이오연료를 대안으로 생각하지 않는 국가들의\n강한 반대로 인해 금번회차에서 해당 의제문서 내용이 긍정적으로 검토되지는\n못하였다.\n이와 관련하여, 선주는 바이오연료의 확대 사용을 찬성하는 입장을 고수할 수', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='못하였다.\n이와 관련하여, 선주는 바이오연료의 확대 사용을 찬성하는 입장을 고수할 수\n밖에 없는 입장이고, 반면 조선소입장에서는 바이오연료 사용의 확대가 신조발\n주 제한으로 작용할 수 있기 때문에 일본에서는 이에 대한 반대 입장을 피력\n해줄 것을 우리나라에 요청하였고, 이와 반면 노르웨이 등에서는 기존 NOx', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='해줄 것을 우리나라에 요청하였고, 이와 반면 노르웨이 등에서는 기존 NOx\n비인증 비율을 30%에서 60%로 확대함에 찬성해 달라는 등 업계 및 국가별\n이해관계가 대립하는 양상을 보이고 있다.\n참여선사(팬오션, HMM) 현장 의견 조회를 바탕으로 Cf 값을 “0”으로 인정을\n받지 못한다고 하더라도 어떠한 구조 등으로 CII 내 적용할 수 있는 Cf 값이', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='받지 못한다고 하더라도 어떠한 구조 등으로 CII 내 적용할 수 있는 Cf 값이\n도출된다면 찬성 한다는 입장을 가져가기로 협의하였으며, 노르웨이에서는\nMGO WtW 배출량의 65% 감축된 값을 가지는 바이오연료만을 인정한다는 입\n장이나 산업계 입장에서는 특정할 수 있는 계수가 한시라도 빨리 도입되는 것\n을 바라고 있는 입장이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='을 바라고 있는 입장이다.\n이에 대해, 향후 한국선급 등을 통해 국내 바이오연료 업계 영향 등을 향후 계\n산하여 대응해 나갈 계획이며, 기본적으로 해운업계의 입장을 우선적으로 고려\n키로 협의하였다.\nMEPC 80차 회의 결과 바이오 연료 사용에 관한 임시지침을 승인하였다. 주요\n내용은 2022년 승인된 CII 가이드라인 상 연료 유형이 관련 가이드라인에 포', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='내용은 2022년 승인된 CII 가이드라인 상 연료 유형이 관련 가이드라인에 포\n함되지 않을 경우, 연료 공급업체가 서면 증거를 제시할 경우 이산화탄소 배출\n변환 계수(Cf) 값을 정의할 수 있도록 하고 있고, 이에 따라 IMO LCA 가이드\n라인을 기반으로한 WtW 온실가스 배출 및 제거를 계산하는 포괄적인 방법이', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='라인을 기반으로한 WtW 온실가스 배출 및 제거를 계산하는 포괄적인 방법이\n개발될 때까지, 국제 인증 체계에 의해 인증된 생태지속성 기준을 충족하고\nWtW 온실가스 배출량이 33 gCO2e/MJ (MGO 94 gCO2e/MJ 대비 65% 감축)\n이하를 만족하는 바이오 연료는 WtW 배출량 값(gCO2eq/MJ)에 저위발열량', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이하를 만족하는 바이오 연료는 WtW 배출량 값(gCO2eq/MJ)에 저위발열량\n(LCV, MJ/g)을 곱하여 해당 연료의 Cf 값으로 사용할 수 있도록 되어 있다.\n어떠한 경우에도 바이오 연료의 Cf 값은 0보다 작을 수 없으며, 혼합연료의\n경우 에너지 기준으로 해당 연료양에 대한 가중 평균을 기준으로 한다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='경우 에너지 기준으로 해당 연료양에 대한 가중 평균을 기준으로 한다.\n이러한 WtW 기준을 충족하지 못할 경우 동등한 화석연료의 Cf와 동일하게 적\n용되며, 임시 지침으로써 IMO LCA 지침서를 통해 바이오연료의 WtW 방법론\n이 적용되는 즉시 철회되는 구조를 가지고 있다.\n임시지침 도입으로 국제인증을 받은 바이오연료 사용을 통한 감축량 추산 결', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='임시지침 도입으로 국제인증을 받은 바이오연료 사용을 통한 감축량 추산 결\n과는 아래와 같다.\n<바이오연료 사용으로 인한 감축량 추산>\n바이오연료\nB100\nB30\nB10\nFAME6)\n39.20%\n11.76%\n3.92%\nHVO7)\n46.59%\n13.98%\n4.66%\n※ 출처 : 한국선급 추산, MGO 대비 65% 감축(32.9g/MJ) 기준', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='4.66%\n※ 출처 : 한국선급 추산, MGO 대비 65% 감축(32.9g/MJ) 기준\n이에 따라, CII 향상을 위해 국제인증을 받은 바이오연료에 대한 Cf 값을 계산\n할 수 있게 되어 국제인증을 받은 바이오연료에 대한 사용이 가능하게 되었다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='할 수 있게 되어 국제인증을 받은 바이오연료에 대한 사용이 가능하게 되었다.\n6) FAME(Fatty Acid Methyl Ester) : 식물성 기름이나 동물성 지방의 지방산을 메틸 알코올\n과 반응시켜 만든 바이오연료로 디젤 엔진 사용 가능\n7) HVO(Hydrotreated Vegetable Oil) : 식물성 기름이나 동물성 지방을 수소와 함께 고온,', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='고압에서 반응시켜 만든 합성 디젤, HVO는 FAME보다 순도가 높음\n외항선사의 경우 연료공급처의 지역적 제한이 없기 때문에 연료 가격만 적정\n선에 형성이 된다면 온실가스 감축방안의 하나로써 바이오연료 적용이 가능해\n질 것으로 전망된다.\n5. 선박평형수 관련 사항\n1) 평형수기록부 양식에 대한 BWM 협약 부속서 제2장 개정안', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='5. 선박평형수 관련 사항\n1) 평형수기록부 양식에 대한 BWM 협약 부속서 제2장 개정안\n2017년 BWM 협약의 발효 후, 위원회는 동 협약을 모니터링하고 개선하기 위\n한 경험축적기(EBP, Experience Building Phase)를 적용하는 결의서\n(Res.MEPC.290(71))을 채택한 바 있다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='(Res.MEPC.290(71))을 채택한 바 있다.\n제78차 MEPC에서는 논의사항 등을 고려하여 BWM 협약 부속서 제2장의 구\n체적인 개정안을 제79차 MEPC에 제출할 것을 요청하였고, 평형수 기록부 개\n정안 초안이 의제문서로 제출되어 논의된 바 있다.(MEPC 79/4/4, MEPC', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='정안 초안이 의제문서로 제출되어 논의된 바 있다.(MEPC 79/4/4, MEPC\n79/4/5) 이에 따라, MEPC 79차에서 설립된 작업반 논의 결과, 평형수 기록부\n에 기입될 항목 및 상황을 A~H까지 코드로 분류하고 각 관리 상황별 평형수\n관리행위에 숫자를 부여하는 코드화 구조를 개정하여 승인하였다. 그러나 이는', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='관리행위에 숫자를 부여하는 코드화 구조를 개정하여 승인하였다. 그러나 이는\n강제조항으로 적용하지 않는 것으로 결정하였으며, 차후 평형수 기록부 작성지\n침을 별도로 개발할 것을 동의하였다.\n이에 따라, 평형수 기록부 작성지침이 MEPC 80차에서 추가로 논의되었으며\n논의 사항을 반영한 평형수 기록부 양식 개정안이 2025년 2월 발효될 예정임', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='논의 사항을 반영한 평형수 기록부 양식 개정안이 2025년 2월 발효될 예정임\n을 고려하여 그전까지 작성 지침을 마련하여 승인키로 합의하였다.\n2) 수질악조건에서 운항하는 선박에 대한 선박평형수관리협약의 적용에 관한\n임시 지침서의 채택\n지난 제71차 MEPC에서 수질 악조건 항만에서 필터 막힘 및 센서 오류 등으', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='지난 제71차 MEPC에서 수질 악조건 항만에서 필터 막힘 및 센서 오류 등으\n로인한 비상조치방안으로 BWE + BWT를 제안하였고, 위원회는 제5차 PPR에\n서 논의토록 하였다. 이는 수질악조건항만에서 우선 평형수 처리장치를 우회하\n여 취수 후 출항하여 평형수 처리장치를 통한 처리된 평형수로 치환하는 작업\n을 인정하여 줄 것을 요청하는 것이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='을 인정하여 줄 것을 요청하는 것이다.\n이에 따라 PPR 5차 이후 논의가 지속되었고, MEPC 77차에서 수질 악조건 항\n만에서 운항하는 선박의 BWE + BWT 적용에 관한 지침서 및 수정안이 제안\n되었으나, 지침서 개발 전 고려되어야 하는 근본적인 요소들을 식별하였고, 이\n를 고려한 논의 및 제안문서 제출을 회원국들에게 요청한바 있다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='를 고려한 논의 및 제안문서 제출을 회원국들에게 요청한바 있다.\n근본적인 요소들에는 평형수처리설비 운전 불가 요건(수질인자, 상황, 시기\n등), 배출기준(D-2) 만족 여부, BWMS 우회운전 조건(비상상황 등), BWE +\nBWT 수행가능 구역 지정 등이 제시되었다.\nMEPC 78차에서는 수질 악조건 항만에서 운항하는 선박의 BWE + BWT 처리', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='MEPC 78차에서는 수질 악조건 항만에서 운항하는 선박의 BWE + BWT 처리\n지침 개발 및 방안 마련을 위한 논의를 지속키로 하였으며 MEPC 79차에서는\n우리나라와 중국과의 공동제출 의제문서를 기초로 하여 수질악조건 항만에서\n평형수의 교환 및 처리 방법 적용에 관한 근본적인 요소에 관한 검토를 완료', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='평형수의 교환 및 처리 방법 적용에 관한 근본적인 요소에 관한 검토를 완료\n했고, 평형수 작업반 검토 내용을 반영한 구체적인 지침서를 제출해 줄 것을\n요청하였다.\nMEPC 80차에서는 회기 중 선박평형수에 대한 작업반을 개설하여 논의를 진\n행하였으며, 작업반 주요 논의 사항 및 결과는 다음과 같다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='행하였으며, 작업반 주요 논의 사항 및 결과는 다음과 같다.\n경험축적기 동안 BWM 협약에 따른 항만국 통제활동을 독려키로 하였고, 수질\n악조건 항만(PCWQ)에서 운항하는 선박에 대한 BWM 협약 적용에 관한 지침\n서의 논의를 시작하여 지침서 작성에 대한 건, 사전 bypass에 대한 논의, 선', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='서의 논의를 시작하여 지침서 작성에 대한 건, 사전 bypass에 대한 논의, 선\n원 친숙화 논의, 이해당사자의 정의 및 협약검토계획서 최종화를 위한 논의 진\n행하였다.\n그러나, 도전적인 수질에서 운영되는 선박에 대한 BWM 협약의 적용에 관하여\n상호간 장시간의 작업을 통해 준비된 초안을 검토하였으나 광범위한 장시간의', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='상호간 장시간의 작업을 통해 준비된 초안을 검토하였으나 광범위한 장시간의\n토론에도 불구하고, 그룹은 지침 초안에 대한 최종안 마련에 실패하였다. 일부\n대표단들이 다음 세션에서 이를 완료하기 위해 세션간 협력 의향을 가지고 있\n다는 점을 언급하였고 MEPC 81차 리뷰그룹 등을 통한 논의를 지속해 나갈\n예정이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='다는 점을 언급하였고 MEPC 81차 리뷰그룹 등을 통한 논의를 지속해 나갈\n예정이다.\n6. 특별해역, 배출통제해역 및 특별민감해역의 식별\n홍해는 1973년 특별해역으로 채택 1983년 및 1988년에 발표되었고, 아덴만은\n1987년 특별해역으로 채택되어 1989년 발효된 바 있다. MARPOL 협약에 따', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='1987년 특별해역으로 채택되어 1989년 발효된 바 있다. MARPOL 협약에 따\n라 RSGA(Red Sea and Gulf of Aden region) 국가들은 육상 수용시설을 충\n분히 확보하고 그 조치사항을 기구에 통보하도록 규정되어 있다.\n이에 따라 RSGA 국가들은 육상 수용시설을 충분히 확보했다고 주장하며 제', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이에 따라 RSGA 국가들은 육상 수용시설을 충분히 확보했다고 주장하며 제\n15규칙(400GT 이상 선박 유성혼합물을 기름필터링장치를 통해 배출) 및 제34\n규칙(유탱커의 특별해역내에서의 기름 또는 유성혼합물을 바다로의 배출 금지)\n에 대한 효력 발생일에 대한 논의를 개시할 것을 제안하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='에 대한 효력 발생일에 대한 논의를 개시할 것을 제안하였다.\n또한, MARPOL 부속서 5 제6규칙(음식쓰레기 배출을 육지로부터 12해리 이상\n이격하여 배출, 25mm mesh 통과) 요건의 효력 발생일에 대한 논의 또한 진\n행할 것을 요청하였다.\n이에 따라 육상수용시설 확보에 대한 정보공유 및 서술한 MARPOL Annex I', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이에 따라 육상수용시설 확보에 대한 정보공유 및 서술한 MARPOL Annex I\n제15규칙, 제34규칙, Annex V 제6규칙의 효력 발생일 제안에 대한 논의가\n이뤄졌다.\nMEPC 80차에 설립된 PSSA 논의를 위한 기술작업반에 NCSR 10(MEPC\n80/WP.8)의 관련 결과를 검토 및 북서 지중해해역을 PSSA로 지정하기 위한', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='80/WP.8)의 관련 결과를 검토 및 북서 지중해해역을 PSSA로 지정하기 위한\nMEPC 결의안을 준비하고, 홍해 및 아덴만의 특별해역에 대한 MARPOL\nAnnex I, V의 규정 효력 발생일을 지정하기 위한 MEPC 결의서를 준비 요청\n하였다.\n기술작업반을 통해 준비된 결의서를 MEPC는 별도 이견 없이 승인하였고, 이', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='하였다.\n기술작업반을 통해 준비된 결의서를 MEPC는 별도 이견 없이 승인하였고, 이\n에 따라 두 결의안의 효력 발생일은 2025년 1월 1일로 결정되었다.\n[IMO 관련 협의 사항]\n1. 벌크선 의제문서 제출 관련\n벌크선 의제문서 제출 건(항만대기 및 선형별 유불리 사항 식별 및 조치) 관련', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='벌크선 의제문서 제출 건(항만대기 및 선형별 유불리 사항 식별 및 조치) 관련\n하여 KMC 및 팬오션과의 현장 협의를 진행하였다. 이 자리에서 벌크선에 대\n한 CII 산정에 있어서의 불합리성 해소를 위한 의제문서 제출 등에 대한 내용\n에 대한 논의가 진행되었고, 400k 급 대형벌크선에 대한 CII 계산 문제점이', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='에 대한 논의가 진행되었고, 400k 급 대형벌크선에 대한 CII 계산 문제점이\n식별되어 국내 대형 벌크선사 협의 및 관련 대응 방안을 논의해 나갈 계획이\n다. 이를 통해 2023년 중 의제문서 작성을 위한 협의 및 데이터 취합을 통한\n의제문서 초안을 작성하고 2024년 초 의제문서를 최종 마무리하여 MEPC 81\n차에 제출할 계획이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='차에 제출할 계획이다.\n2. 중장기 조치에 대한 의견 수렴\n중장기 조치 도입에 관한 사항 중 IMO 와 EU 의 규제 중복사항 (FuelEU\nMaritime 및 GFS) 등에 대한 탄소세 부과 시 이중 부담이 있을 수 있는 점에\n대한 의견조회 결과 FuelEU Maritime 규정에 IMO 등 상위 규제가 적용될', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='대한 의견조회 결과 FuelEU Maritime 규정에 IMO 등 상위 규제가 적용될\n경우 재검토(Review) 규정이 명시되어 있어 중복규제 등을 조정할 수 있을 것\n이라는 사항을 확인하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'})]

# %%
splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)
loader = UnstructuredFileLoader(file_path)
loader.load_and_split(text_splitter=splitter)
# Out:
# [Document(page_content='[MEPC 80 결과보고서, 2023.7.10.]\nMEPC 80차 결과보고\n한국해운협회 해무팀\n해양환경보호위원회(MEPC) 80차 개요\n1. 일반사항\n회의명 : 제80차 해양환경보호위원회(MEPC 80)\n기 간 : 2023. 07. 03. ~ 07. 07. (5일간)\n장 소 : 영국 런던 IMO 본부\n참 석 : 해양수산부 등 대표단 34명\n주요논의 주제\n⦁평형수내 유해생물(BWM)\n⦁대기오염, 선박 에너지효율(EEDI)\n⦁선박으로부터의 GHG 배출 감축(초기전략 개정, 중기조치 초안)\n⦁선박 배출 해양플라스틱 조치계획 개발\n⦁특별해역, 배출통제해역 및 특별민감해역의 식별 등 16개 의제\n2. MEPC 80차 주요 결정 사항', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='⦁특별해역, 배출통제해역 및 특별민감해역의 식별 등 16개 의제\n2. MEPC 80차 주요 결정 사항\n2030~2050 감축목표(Level of Ambition)\n⦁2050년 경(By or around 2050) 국제해운 탄소중립 실현\n⦁2030년까지 저·무탄소 연료 및 기술 5~10% 사용\n중간 지표(indicative checkpoint) 설정\n⦁2050년 탄소중립 실현을 위해, 2008년 온실가스 총 배출량 대비 2030\n년까지 20~30%, 2040년까지 70~80% 감축 노력\n중기 조치(Mid-term measure)\n⦁연료유 표준제(GFS, Goal based Fuel Standard)와 온실가스 감축 수\n준에 따라 일정 부담금을 부과하는 결합조치 도입에 합의\n⦁해운산업 및 국가별 영향 등을 분석하기 위한 영향평가 착수, 구체 이행', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='⦁해운산업 및 국가별 영향 등을 분석하기 위한 영향평가 착수, 구체 이행\n방안 논의 후 2027년 5월 시행 예정\n[의제별 논의 경과 및 진행사항]\n1. IMO 온실가스 감축 초기전략의 개정\n국제해운 규제기관인 IMO 에서는 2018년 IMO 온실가스 감축 초기전략 채택\n시 국제해운에서 발생하는 연간 총 온실가스 배출량을 2008년 대비 2050년까\n지 절반으로 감축하겠다는 의욕수준을 설정한 바 있다. 이번 MEPC 80차에서\n강화된 IMO 온실가스 감축 초기전략이 논의 및 채택되었다.\nMEPC 77차 이후 MEPC 80차 채택을 목표로 초기전략 개정 작업을 개시하였', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='MEPC 77차 이후 MEPC 80차 채택을 목표로 초기전략 개정 작업을 개시하였\n고, 회의 참여국들은 지구 온난화의 심각성 인식 등으로 초기전략 목표 강화\n필요성에 대한 전반적인 공감대를 형성하였다.\n2050년 초기전략 의욕수준에 대하여 대부분의 대표단들은 국제해운의 온실가\n스 배출이 가능한 빨리 정점에 도달하고, 2050년까지 그 배출을 없게 하는 것\n에 모두 동의하였다. 다만, 2030년과 2040년의 감축목표 설정에 있어 여러 의\n견이 제시되었고 작업반(WG)을 MEPC 80차 회기중 개설하여 상세 논의를 진\n행하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='견이 제시되었고 작업반(WG)을 MEPC 80차 회기중 개설하여 상세 논의를 진\n행하였다.\n작업반 논의전 온실가스 감축 초기전략에 대하여 MEPC 80 개최전 회기간 작\n업반 회의(ISWG-GHG 15, 6.26~6.30)에서 개정안에 대한 논의가 진행되었다.\n2050년 목표에 대해 회원국들은 Net-zero, Phase-out, zero emission 등\n다양한 표현을 사용하여 배출량 0를 달성해야 함을 주장하였으며, 이 중\nUNFCCC에서 이미 사용하고 있는 용어인 Net-zero의 선호를 확인하였다.\n목표연도에 대해 “Mid-century”와 “at least before 2050”으로 의견이 양분\n되었다. “Mid-century”의 주장 근거는 글래스고 기후 합의 문구 내용에 포함', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='되었다. “Mid-century”의 주장 근거는 글래스고 기후 합의 문구 내용에 포함\n되었음을 근거로 하였으며, 지지 국가는 중국, 브라질, 아르헨티나, 남아공, 우\n르과이, 사우디아라비아, 벨라루스, 러시아, 쿠바, 파라과이, 인도네시아, 페루,\n베네수엘라, 에콰도르 등이 지지하였다.\n글래스고 기후 합의문 문구 : The main goal was to secure global net\nzero by mid-century and keep a maximum of 1.5 C degrees of\nwarming within reach.\n“at least before 2050”을 지지하는 근거는 IPCC AR 61) 보고서 문구를 인용\n한 것으로써 지지국가는 우리나라, EU, 미국, 영국, 캐나다, 노르웨이, 군소도', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='한 것으로써 지지국가는 우리나라, EU, 미국, 영국, 캐나다, 노르웨이, 군소도\n서국, 일본, 파나마, 싱가폴, 몰디브, 호주, 나미비아 등이다.\n중간목표 설정에 대하여 2050년 탈탄소화 목표 달성을 위해 2030년(감축량,\n연료/에너지 사용률), 2040년 중간목표의 필요성을 지지하는 국가와 현재 단\n계에서 불필요하다는 주장을 하는 국가로 구분되었다.\n반면, 중국 등 개도국을 중심으로 중간목표 설정에 반대하였으나, 국제해운 에\n너지(Zero 또는 Near-zero) 목표에 대해서는 일부 국가(인도, UAE)에서 지지\n의사를 표시하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='너지(Zero 또는 Near-zero) 목표에 대해서는 일부 국가(인도, UAE)에서 지지\n의사를 표시하였다.\n논의 결과 초기전략 개정초안을 최종보고서 내용에 포함하여 MEPC 80차로\n제출하였다.\n이에 대해 MEPC 80차에서는 ISWG-GHG 14차 및 15차 결과에 대한 회원국\n들의 의견을 수렴하였고, 대부분의 회원국들은 기후위기의 심각성을 고려하여\n이번 MEPC 80차에서 2023 초기전략 개정안을 채택해야하며, 공정하고 정의\n로운 전환을 보장할 것에는 전반적인 동의를 확인하였으나, 구체적인 사항에\n대해서는 개도국 및 선진국 간의 의견이 양분되었다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='대해서는 개도국 및 선진국 간의 의견이 양분되었다.\n선진국 및 군소도서국에서는 IMO의 감축목표는 파리협약의 온도 목표(1.5도)\n와 일치하여야 하며 이를 위하여 2030년 2040년 Indicative checkpoint 및\n2050년 넷제로를 의욕수준으로 결정할 것을 주장하였다. 중기조치에 있어 경\n제적 요소와 기술적 요소를 결합한 조치가 중기조치로써 고려되어야 하고, 중\n기조치를 2025년에 채택하기 위하여 MEPC 80차에서 종합영향평가를 착수할\n것을 제안하였다. 특히, 군소도서국의 경우 경제적 요소로서 Universial Levy\n가 도입되어야 함을 특별히 강조하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='가 도입되어야 함을 특별히 강조하였다.\n1) IPCC Sixth Assessment Report : 기후 변화에 관한 유엔 정부 간 패널의 여섯 번째 평가 보고서는 기후 변화에 관한 과학적, 기술적, 사회 경제적 정보를 평가 하는 일련의 보고서\n개도국은 국제해운이 전 세계 무역의 80%를 차지하므로 해운에서의 잘못된\n시그널은 전 세계에 무역의 혼란으로 식량, 에너지 문제를 일으킬 수 있다는\n점을 강조하였다. 이에 따라 실현 가능하며 현실적인 목표로 2050년 목표를\n“net zero by or around mid-of century”로 설정할 것을 주장하였다. 중기', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='“net zero by or around mid-of century”로 설정할 것을 주장하였다. 중기\n조치에 있어서 Levy는 무역가격을 상승시켜 개도국에 식량 및 에너지 문제를\n초래할 수 있으므로 적절한 중기조치가 아님을 주장하였다.\n논의결과 초기전략은 기존의 2050년까지 2008년 총 온실가스 배출량 대비\n50% 감축하기로 한 기존 목표를 상향하여 2030년까지 20~30%를, 2040년까\n지 70~80%를 감축하고 2050년경(By or around 2050)에는 순 배출량 제로\n(Net-Zero)를 달성하는 것을 목표로 설정하였다.\n다만, 2030~2040년 감축량의 경우 각 국가의 자율적 감축 노력을 촉진하기', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='다만, 2030~2040년 감축량의 경우 각 국가의 자율적 감축 노력을 촉진하기\n위한 목적으로 의무적 달성 목표라기보다는 점검 차원의 지표로써 작용한다는\n점에서 2050년 목표와 차이점을 가지고 있다.\n또한 2030년까지 저·무탄소 연료 및 기술을 5~10% 사용하도록 노력함에 동의\n하였다.\n온실가스 감축과 관련한 CCS(탄소포집)에 대한 논의로써 대한민국 제출문서2)\n관련하여 의견조회를 통해 MEPC 80차 후 개설될 ISWG-GHG 16차에 포함하\n여 논의할 것을 제안하였다. 우리나라 등은 OCCS 기술의 감축잠재력 및 산업', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='여 논의할 것을 제안하였다. 우리나라 등은 OCCS 기술의 감축잠재력 및 산업\n계의 많은 관심을 고려하여 빠른 논의 착수를 주장하며 의장이 제안한\nISWG-GHG 16에 포함할 것을 찬성(노르웨이, 라이베리아, 일본, 중국, 쿡아일\n랜드, 영국, CESA)하였다.\n스페인 등(미국, 독일, 네덜란드, 터키, 솔로몬제도)은 현재 시점에서 작업 계\n획 설정 구성은 시기상조이고, LCA 가이드라인 측면에서 함께 고려가 필요함\n을 주장하였다.\n논의 결과 ISWG-GHG 16차에서 OCCS(선상탄소포집) 논의를 착수하기로 합', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content="을 주장하였다.\n논의 결과 ISWG-GHG 16차에서 OCCS(선상탄소포집) 논의를 착수하기로 합\n의하였으며, 안전성 확보를 위하여 MSC 등 연관 위원회에 검토를 요청하기로\n하였다.\n2) MEPC 80/7/7 The use of onboard carbon capture systems within IMO's regulatory framework\n온실가스 초기전략 설정에 대해, 2050년 Net-Zero 달성을 위한 보고서 등에\n따르면 2030년 2008년 대비 약 50%감축, 2040년 약 70%의 감축이 필요한\n것으로 확인된다. 현재 설정된 2030년 목표 20~30%, 2040년 70~80% 감축\n목표는 2040년도 목표는 Net-Zero 경로에 부합하지만 2030년 목표는 경로에\n부합하지 않는 상황이며, 이는 기술, 인프라 등의 보급 확산이 지수함수적 성", metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='부합하지 않는 상황이며, 이는 기술, 인프라 등의 보급 확산이 지수함수적 성\n격을 가지고 있기 때문인 것으로 파악된다.\n현재 선사들이 직면하고 있는 CII 규제는 2026년 리뷰 후 감축 경로에 맞춰\n연간 감축률이 상향될 것으로 예상된다. 이는 2050년 감축목표가 50%에서\n0%(Net-Zero)로 상향됨에 따라 어떠한 경로가 설정되더라도 현행 연간 2%\n감축보다 상향될 수 밖에 없는 상황인 것으로 확인된다.\n이에 따라, 2030년 20% 감축 수준을 달성하기 위해 바이오연료 적용 및 선박', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이에 따라, 2030년 20% 감축 수준을 달성하기 위해 바이오연료 적용 및 선박\n운항최적화, 그리고 선박 에너지효율향상장치(ESD) 적용 등을 진행하고 일부\n선대의 무·저탄소 선박 전환이 필요할 것으로 예상된다. 2040년의 70% 감축\n목표 달성을 위해선 무·저탄소 선박이 전체선대의 절반 이상의 비중을 차지해\n야할 것으로 예상되는 상황이다. 2030년 감축목표가 IMO 보고서 등에서 논하\n고 있는 45% 이하로 설정되어 이를 보완하기 위해 2030년 새롭게 저·무탄소\n연료 및 기술 5% 사용을 목표로 추가한 것으로 사료된다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='연료 및 기술 5% 사용을 목표로 추가한 것으로 사료된다.\n전과정(WtW) 기준의 무탄소 연료의 조기 도입을 위한 산업계 협력을 통해 인\n프라 및 기술의 조기 확보 추진이 필요한 상황이며, 이번에 새롭게 추가된 저·\n무탄소 연료의 2030년까지 5%~10% 사용에 따른 논의경과에 대한 확인이 필\n요한 상황이다.\n2. 중기후보조치 선정 및 검토\nMEPC 80차에서 논의를 위해 사전 제안된 중기후보조치는 크게 다섯가지로\n분류될 수 있다.\n1) 무배출 선박 인센티브(ZESIS3)) 제도 (일본)', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='분류될 수 있다.\n1) 무배출 선박 인센티브(ZESIS3)) 제도 (일본)\n일본에서 제안한 무배출 선박 인센티브(ZESIS) 제도로 전과정 온실가스 배출\n선박에 기여금을 부과하고, 저/무배출 연료를 사용하는 선박에 인센티브를 부\n여하는 “Feebate Mechanism”과 기존 GFS를 결합시킨 형태의 제도이다.\nGFS 기준을 미달성한 선박은 달성한 선박으로부터 SRU(Surplus Reward\nUnit) 또는 RU(Remedial Unit)를 구입하여 부족분을 충당함으로써 규제를 이\n행할 수 있고, 무탄소 연료를 선도입한 선행자(First Mover)는 배출권 판매', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='행할 수 있고, 무탄소 연료를 선도입한 선행자(First Mover)는 배출권 판매\n등을 통해 인센티브 수혜를 받을 수 있게 된다. 그러나 SRU의 경우 배출권\n거래제의 ‘배출권’과 유사하게 초과 달성한 선박에 지급되는 보상개념으로 판\n매/구입 가격은 시장에서 결정되게 되어 가격 불확실성 등 선사 부담이 커질\n것으로 예상되는 상황이다. 이에 대비하여 RU는 IMO에서 결정한 고정가격으\n로 ‘배출권’을 구매하는 개념으로 현재 논의되고 해운업계에서 선호하고 있는', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='로 ‘배출권’을 구매하는 개념으로 현재 논의되고 해운업계에서 선호하고 있는\n가격 확정을 통한 예측이 가능한 탄소세(Levy) 개념과 유사하여 해운업계 입\n장을 고려하여 협회에서는 SRU 보다는 RU로의 도입을 요청하였고, 우리나라\n는 산업계 의견을 반영하여 지속적으로 RU로 의견을 개진하고 있다.\n2) 연료유 표준제도(GFS) 및 온실가스 부담금(GHG Levy)제도의 결합 (EU)\nEU에서 제안한 GFS+GHG Levy 결합제도는 규제 미준수 선박의 갑작스런 운\n항불가 사항으로 야기되는 국제물류 혼란을 방지하고자 배출권 구매 또는 벌', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='항불가 사항으로 야기되는 국제물류 혼란을 방지하고자 배출권 구매 또는 벌\n금제도 등을 통해 규제를 달성하고 운항할 수 있도록 규제 이행의 유연성을\n주는 체계인 유연성 메커니즘을 포함하는 GFS 제도와 전과정 온실가스 배출\n선박에 기여금을 부과하는 GHG Levy를 결합한 형태의 제도를 제안하고 있다.\n3) 국제해사지속가능성 연료 및 기금 메커니즘(IMSF&F) (중국)\nIMSF&F(International Maritime Sustainability Fuels and Fund)는 기존\n중국이 아르헨티나, 브라질 등과 함께 제안한\nIMSF&R(International\nMaritime Sustainability Funding and Reward)을 보완한 제안으로 타국가', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='IMSF&R(International\nMaritime Sustainability Funding and Reward)을 보완한 제안으로 타국가\n에서 제안된 조치들을 포함하고 있다. 주요 차이점으로는 기존 IMSF&R의 경\n우 기준점 설정을 위해 탄소집약도지표(CII)를 활용하였으나, 대체연료 및 혁신\n기술을 촉진할 수 있는 지표 사용을 위해 GFI(GHG Fuel Intensity, 연료에너\n지의 GHG 집약도)로 대체하였다.\n이를 통해, 온실가스 이중계산을 방지하기 위해 각 국가별 온실가스 인벤토리\n3) ZESIS : Zero-Emission Shipping Incentive Scheme\n에 포함되는 연료의 제품 생산 및 운송-유통 단계의 온실가스 배출량은 선박', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='에 포함되는 연료의 제품 생산 및 운송-유통 단계의 온실가스 배출량은 선박\n에서의 배출량으로 포함하지 않아 TtW 기반 온실가스 집약도를 제한하고 기\n준보다 초과 달성한 선박에 SRU를 지급하고 이를 미달성 선박에 판매하여 수\n익 창출이 가능한 구조이다. 또한, LCA 가이드라인에서 인정하는 지속가능연\n료를 사용했을 경우에만 SRU를 부여하도록 하여 WtW기반의 저배출량 연료\n사용을 유도하는 구조를 갖추고 있다.\n4) 온실가스 연료유 표준제도의 단순화 제안 (ICS)', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='4) 온실가스 연료유 표준제도의 단순화 제안 (ICS)\nEU에서 제안한 GFS의 이행절차 복잡성으로 인해 실현가능한 감축률(2030년\n까지 5%)을 설정하고 제도를 단순화시킬 것을 제안하였다. EU의 GFS는 규제\n미달성시 유연성 메커니즘을 통해 규제를 이행할 수 있으나, 이러한 제도가 오\n히려 복잡성을 초래하는 점을 지적하였다.\n또한, 선박 저유황유 도입과 유사하게 선박이 부득이한 사정(항구 인프라 부족\n등)으로 대체연료의 수급이 불가할 경우 기국 허가를 통해 사용유예 가능 조항\n(FONAR, Fuel Oil Non Availability Report) 신설을 제안하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='(FONAR, Fuel Oil Non Availability Report) 신설을 제안하였다.\n5) 국제해사기구 해사 지속가능성 기금 및 보상 메커니즘 (ICS)\nIMSF&R 메커니즘에 대하여 ICS에서는 CO2톤당 부담금을 징수하여 기금을 마\n련하고, 이를 대체연료 사용선박에 대한 보상금과 개도국 지원, R&D 등에 활\n용할 것을 제안하였다. 이중 적어도 5% 이상의 대체연료 사용선박에 보상금을\n제공할 수 있도록 하였으며, 기여 보상금 수준을 5년마다 수정 검토한다는 내\n용을 담고 있다.\n이에 대하여 ISWG-GHG 15차에서는 중기조치 논의에 있어서 다음의 7가지\n논의사항에 대한 회원국 의견을 요청하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='논의사항에 대한 회원국 의견을 요청하였다.\n① 기술적 요소와 관련하여, GFS를 추가 개발하는 것으로 의견이 수렴되었음\n에 주목하여, 작업반은 목표기반 및 선박 탄소집약도의 단계적 감소를 의\n무화하는 에너지 표준을 추가 개발할 것을 권고하는 단계인지?\n② 경제적 요소와 관련하여, 다양한 제안에 대한 공통 요소가 증가하였으나 다\n양한 입장도 식별되었음에 주목하여 작업반은 1) 경제적 요소로써의 단일\n제안(Levy, feebate, reward, ECTS 등)을 권고하거나 2) 현 단계에서의', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='제안(Levy, feebate, reward, ECTS 등)을 권고하거나 2) 현 단계에서의\n유연성을 유지할 필요성을 인지하여, 회원국 영향, 기금 조성, 관리, 분배\n등에 주목하여 3단계에서 추가 평가 및 정교화를 권고하는 단계인지?\n③ 어떠한 중요한 요소 또는 공통점이 3단계에서 고려되어야 하는지(LCA 고\n려 방안, 부정적 영향 해소 등)?\n④ 작업반이 단일, 결합조치 또는 개별적 요소의 개발을 권고하는 단계인지?\n⑤ MEPC 80에서 결합조치의 종합 영향 평가를 시작할 것을 권고하는데 동의\n하는지?', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='⑤ MEPC 80에서 결합조치의 종합 영향 평가를 시작할 것을 권고하는데 동의\n하는지?\n⑥ 중기조치의 완료, 채택, 발효일에 대한 목표 일정이 어떻게 되는지?\n⑦ 추가 개발되어야 하는 기술적 및 경제적 요소와 결합 조치의 어떠한 부분\n이 개정 전략의 섹션 4에 포함되어야 하는지?\n다수 회원국이 위 질문에 대한 각각의 의견을 표명하기 보다는 선호하는 기술\n적 및 경제적 조치, 중기조치 도입 일정 및 종합 영향평가 관련 의견 위주로\n의견을 제시하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content="의견을 제시하였다.\n대한민국, EU, 군소도서국은 기술적 요소로써 GFS와 경제적 요소로써 Levy를\n결합한 결합조치 도입을 주장하였다. 또한, 국가별 준비 수준이 상이하므로\nGFS에 대한 유연성 메커니즘이 도입되어야 한다는 주장이다. 중기조치는\nWtW 기반이어야 하며, MEPC 80에서 3단계 논의를 시작하여 '25년에 채택\n및 '27년 발효를 목표로 해야한다는 의견을 밝혔다.\n개도국 등4)은 중국에서 제안한 IMSF&F이 기술적 및 경제적 요소를 결합한\n조치로써 이를 지지하였다. Levy는 시장과의 거리가 있는 일부 회원국에게 관", metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='조치로써 이를 지지하였다. Levy는 시장과의 거리가 있는 일부 회원국에게 관\n련 비용을 전가함으로써 국가간 격차를 야기할 뿐만 아니라, Levy는 신규 체\n제로써 규제 이행 준비에 있어서 행정적 부담이 발생하며, 배출량 감축이 목표\n가 아닌 기금 조성을 위한 조치이므로 Levy 도입에 반대하였다. 이에 대하여\n경제적 요소에 따른 수익은 해운분야에만 분배되어야 한다는 점을 강조했다.\n(타 분야로의 수익 분배 반대) 또한, 조치 채택 전 종합영향평가가 반드시 완', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='(타 분야로의 수익 분배 반대) 또한, 조치 채택 전 종합영향평가가 반드시 완\n료되어야 하며, 구체적인 시기를 언급하진 않았으나 단기조치 도입시 식별된\n문제사항들을 상기하여 이미 합의된 절차에 따라서 이행해야 한다는 의견을\n피력했다.\n4) 중국, 아르헨티나, 브라질, 페루, 칠레, 우루과이, 남아프리카, 쿠바, 과테말 라, 에콰도르, 베네수엘라, 파라과이, 사우디아라비아, 대만, 방글라데시, 벨 라루스, 북한, 러시아 등\n선진국 등5)은 GFS + 경제적 조치를 결합한 결합조치를 지지하며, 경제적 조', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='선진국 등5)은 GFS + 경제적 조치를 결합한 결합조치를 지지하며, 경제적 조\n치로써 어떠한 조치(levy, feebate, flat rate)를 고려할지와 GFS와 어떻게 결\n합할 것인지에 대해서는 3단계에서 추가로 논의할 것을 주장하였다.\n호주는 결합조치를 지지하며 기술적 요소의 GFS와\nIMSF&F는 유사하나\nIMSF&F가 간략하므로 이를 지지하며, 영국에서 제안한 종합영향평가 제안을\n지지하였다.\n노르웨이는 기술적 요소로써 GFS 도입을 지지하며, 경제적 요소로써 일본의\nZESIS 제안이 적절한 것으로 보이나 현재 단계에서 이를 결정하기 보다는 3', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='ZESIS 제안이 적절한 것으로 보이나 현재 단계에서 이를 결정하기 보다는 3\n단계에서 추가 논의할 것을 주장하였다.\n이와 관련하여 우리나라는 제안된 조치에 대한 평가 결과 온실가스 연료유 표\n준제도(GFS)와 온실가스 부담금제도(Levy)가 최적 제안임을 산업계 의견을 반\n영하여 우리나라 훈령으로 확정하였다. 또한 중기조치 논의에 따른 유연성 메\n커니즘 고려시 배출권 거래제 개념을 담고 있는 SRU가 아닌 고정 가격을 지\n불하는 탄소세 개념인 RU를 적용할 것을 지속적으로 요청하여 우리나라 훈령\n에 반영되었다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='에 반영되었다.\n이와 관련 각 회원국들은 목표 달성을 위해 연료별 온실가스 집약도를 단계적\n으로 제한하는 연료유 표준제(GFS, goal based Fuel Standard)와 온실가스\n감축 수준에 따라 일정 비용을 부과하는 규제(경제적 규제)가 결합된 결합조치\n(Basket Measure)를 도입하기로 합의하였다.\n결합조치는 기술적 요소와 경제적 요소를 함께 고려하는 결합된 조치로써 규\n제 도입으로 인해 국가, 해운산업 등에 미칠 수 있는 영향 분석이 완료되고 규\n제 수준·대상 등에 대한 구체적인 기준과 이행방안이 마련된 후 2027년에 시\n행될 예정이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='행될 예정이다.\n5) 영국, 미국, 캐나다, 싱가포르, 뉴질랜드등\n<향후 중기조치 개발 계획>\n시기\n종합영향평가*\n중기조치 개발\nMEPC 80(‘23.7)\n종합영향평가 착수\n중기조치 개발 착수\nMEPC 81(‘24.4)\n중간보고서 제출\n결합조치 이행 방안 마련\nMEPC 82(‘24.10)\n최종보고서 제출\nMEPC 83(‘25.4)\n조치 승인\nMEPC 83 – 84\n사이(‘25.10)\n조치 채택\nMEPC 84(‘26, 봄)\nMEPC 85(‘26, 가을)\n‘27.5\n조치 시행\n3. LCA 지침서 최종보고서 검토\nIMO에서는 연료의 생산부터 사용단계까지의 온실가스 배출량 평가 지침 마련', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='IMO에서는 연료의 생산부터 사용단계까지의 온실가스 배출량 평가 지침 마련\n을 위한 회기간 실무작업반을 ‘22.3~’23.7 까지 운영한 바 있으며 그에 따른\n최종보고서를 ISWG-GHG 15차에 제출했고, MEPC 80차에서 채택되었다.\n향후 작업방향에 대한 방법론적 요소에 대한 추가 작업 필요사항을 식별하였\n으며, 특히 직접토지이용변화 및 CCS 등과 같은 산정 방법론에 대한 개선 및\n개발 측면에서의 추가적인 기술 작업 필요성이 식별되었다.\n이에 따라, LCA 지침서 회기간 실무작업반에서 추가적인 지침서에 대한 개발', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이에 따라, LCA 지침서 회기간 실무작업반에서 추가적인 지침서에 대한 개발\n특히, 연료의 지속가능성 및 제3자 검정-인증 관련 지침서 개발의 필요성이\n확인되었고 유럽에서 전문가 워크숍(MEPC 81차 전 개최)이 제안되었다.\n또한, 새로운 기술의 발전과 과학적 지식이 지침서에 반영될 수 있도록 LCA\n지침에 대한 지속적인 과학적 검토가 필요하다는 추가 작업사항이 확인되어\nISWG-GHG 16차를 통해 MEPC 81차에 기본 배출계수 등이 포함되는 서면\n보고서를 제출할 예정이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='보고서를 제출할 예정이다.\n이러한 WtW로 평가된 연료 적용 및 효과를 보기 위해서는 2027년 도입예정\n인 GFS+Levy의 적용이 필요하며, 연료 공급지역 및 항로별 취항선사 적용을\n위한 유불리 사항 파악 및 케이스별 대처가 필요한 상황이다.\n4. 바이오연료 사용 임시지침 승인\n지속 가능한 바이오연료를 현행 IMO 규제(DCS, CII 등)에 조기 적용할 수 있\n도록 CO2 배출계수를 ‘0’으로 산정할 것을 제안하는 결의서가 인도에 의해 제\n안되었다. 이에 대해 LCA 지침서 추가개발까지의 시간이 추가적으로 필요하고', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='안되었다. 이에 대해 LCA 지침서 추가개발까지의 시간이 추가적으로 필요하고\n규제의 불확실성에 대한 조기 해소에 필요한 조치로 확인되어 산업계의 필요\n성을 정부대표단에 전달한 바 있으며 이를 반영하여 우리나라는 찬성 의견을\n개진하였다. 그러나 미국 등 바이오연료를 대안으로 생각하지 않는 국가들의\n강한 반대로 인해 금번회차에서 해당 의제문서 내용이 긍정적으로 검토되지는\n못하였다.\n이와 관련하여, 선주는 바이오연료의 확대 사용을 찬성하는 입장을 고수할 수', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='못하였다.\n이와 관련하여, 선주는 바이오연료의 확대 사용을 찬성하는 입장을 고수할 수\n밖에 없는 입장이고, 반면 조선소입장에서는 바이오연료 사용의 확대가 신조발\n주 제한으로 작용할 수 있기 때문에 일본에서는 이에 대한 반대 입장을 피력\n해줄 것을 우리나라에 요청하였고, 이와 반면 노르웨이 등에서는 기존 NOx\n비인증 비율을 30%에서 60%로 확대함에 찬성해 달라는 등 업계 및 국가별\n이해관계가 대립하는 양상을 보이고 있다.\n참여선사(팬오션, HMM) 현장 의견 조회를 바탕으로 Cf 값을 “0”으로 인정을', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='참여선사(팬오션, HMM) 현장 의견 조회를 바탕으로 Cf 값을 “0”으로 인정을\n받지 못한다고 하더라도 어떠한 구조 등으로 CII 내 적용할 수 있는 Cf 값이\n도출된다면 찬성 한다는 입장을 가져가기로 협의하였으며, 노르웨이에서는\nMGO WtW 배출량의 65% 감축된 값을 가지는 바이오연료만을 인정한다는 입\n장이나 산업계 입장에서는 특정할 수 있는 계수가 한시라도 빨리 도입되는 것\n을 바라고 있는 입장이다.\n이에 대해, 향후 한국선급 등을 통해 국내 바이오연료 업계 영향 등을 향후 계', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='이에 대해, 향후 한국선급 등을 통해 국내 바이오연료 업계 영향 등을 향후 계\n산하여 대응해 나갈 계획이며, 기본적으로 해운업계의 입장을 우선적으로 고려\n키로 협의하였다.\nMEPC 80차 회의 결과 바이오 연료 사용에 관한 임시지침을 승인하였다. 주요\n내용은 2022년 승인된 CII 가이드라인 상 연료 유형이 관련 가이드라인에 포\n함되지 않을 경우, 연료 공급업체가 서면 증거를 제시할 경우 이산화탄소 배출\n변환 계수(Cf) 값을 정의할 수 있도록 하고 있고, 이에 따라 IMO LCA 가이드', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='변환 계수(Cf) 값을 정의할 수 있도록 하고 있고, 이에 따라 IMO LCA 가이드\n라인을 기반으로한 WtW 온실가스 배출 및 제거를 계산하는 포괄적인 방법이\n개발될 때까지, 국제 인증 체계에 의해 인증된 생태지속성 기준을 충족하고\nWtW 온실가스 배출량이 33 gCO2e/MJ (MGO 94 gCO2e/MJ 대비 65% 감축)\n이하를 만족하는 바이오 연료는 WtW 배출량 값(gCO2eq/MJ)에 저위발열량\n(LCV, MJ/g)을 곱하여 해당 연료의 Cf 값으로 사용할 수 있도록 되어 있다.\n어떠한 경우에도 바이오 연료의 Cf 값은 0보다 작을 수 없으며, 혼합연료의', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='어떠한 경우에도 바이오 연료의 Cf 값은 0보다 작을 수 없으며, 혼합연료의\n경우 에너지 기준으로 해당 연료양에 대한 가중 평균을 기준으로 한다.\n이러한 WtW 기준을 충족하지 못할 경우 동등한 화석연료의 Cf와 동일하게 적\n용되며, 임시 지침으로써 IMO LCA 지침서를 통해 바이오연료의 WtW 방법론\n이 적용되는 즉시 철회되는 구조를 가지고 있다.\n임시지침 도입으로 국제인증을 받은 바이오연료 사용을 통한 감축량 추산 결\n과는 아래와 같다.\n<바이오연료 사용으로 인한 감축량 추산>\n바이오연료\nB100\nB30\nB10\nFAME6)\n39.20%\n11.76%\n3.92%', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='<바이오연료 사용으로 인한 감축량 추산>\n바이오연료\nB100\nB30\nB10\nFAME6)\n39.20%\n11.76%\n3.92%\nHVO7)\n46.59%\n13.98%\n4.66%\n※ 출처 : 한국선급 추산, MGO 대비 65% 감축(32.9g/MJ) 기준\n이에 따라, CII 향상을 위해 국제인증을 받은 바이오연료에 대한 Cf 값을 계산\n할 수 있게 되어 국제인증을 받은 바이오연료에 대한 사용이 가능하게 되었다.\n6) FAME(Fatty Acid Methyl Ester) : 식물성 기름이나 동물성 지방의 지방산을 메틸 알코올\n과 반응시켜 만든 바이오연료로 디젤 엔진 사용 가능\n7) HVO(Hydrotreated Vegetable Oil) : 식물성 기름이나 동물성 지방을 수소와 함께 고온,', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='7) HVO(Hydrotreated Vegetable Oil) : 식물성 기름이나 동물성 지방을 수소와 함께 고온,\n고압에서 반응시켜 만든 합성 디젤, HVO는 FAME보다 순도가 높음\n외항선사의 경우 연료공급처의 지역적 제한이 없기 때문에 연료 가격만 적정\n선에 형성이 된다면 온실가스 감축방안의 하나로써 바이오연료 적용이 가능해\n질 것으로 전망된다.\n5. 선박평형수 관련 사항\n1) 평형수기록부 양식에 대한 BWM 협약 부속서 제2장 개정안\n2017년 BWM 협약의 발효 후, 위원회는 동 협약을 모니터링하고 개선하기 위\n한 경험축적기(EBP, Experience Building Phase)를 적용하는 결의서', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='한 경험축적기(EBP, Experience Building Phase)를 적용하는 결의서\n(Res.MEPC.290(71))을 채택한 바 있다.\n제78차 MEPC에서는 논의사항 등을 고려하여 BWM 협약 부속서 제2장의 구\n체적인 개정안을 제79차 MEPC에 제출할 것을 요청하였고, 평형수 기록부 개\n정안 초안이 의제문서로 제출되어 논의된 바 있다.(MEPC 79/4/4, MEPC\n79/4/5) 이에 따라, MEPC 79차에서 설립된 작업반 논의 결과, 평형수 기록부\n에 기입될 항목 및 상황을 A~H까지 코드로 분류하고 각 관리 상황별 평형수\n관리행위에 숫자를 부여하는 코드화 구조를 개정하여 승인하였다. 그러나 이는', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='관리행위에 숫자를 부여하는 코드화 구조를 개정하여 승인하였다. 그러나 이는\n강제조항으로 적용하지 않는 것으로 결정하였으며, 차후 평형수 기록부 작성지\n침을 별도로 개발할 것을 동의하였다.\n이에 따라, 평형수 기록부 작성지침이 MEPC 80차에서 추가로 논의되었으며\n논의 사항을 반영한 평형수 기록부 양식 개정안이 2025년 2월 발효될 예정임\n을 고려하여 그전까지 작성 지침을 마련하여 승인키로 합의하였다.\n2) 수질악조건에서 운항하는 선박에 대한 선박평형수관리협약의 적용에 관한\n임시 지침서의 채택', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='임시 지침서의 채택\n지난 제71차 MEPC에서 수질 악조건 항만에서 필터 막힘 및 센서 오류 등으\n로인한 비상조치방안으로 BWE + BWT를 제안하였고, 위원회는 제5차 PPR에\n서 논의토록 하였다. 이는 수질악조건항만에서 우선 평형수 처리장치를 우회하\n여 취수 후 출항하여 평형수 처리장치를 통한 처리된 평형수로 치환하는 작업\n을 인정하여 줄 것을 요청하는 것이다.\n이에 따라 PPR 5차 이후 논의가 지속되었고, MEPC 77차에서 수질 악조건 항\n만에서 운항하는 선박의 BWE + BWT 적용에 관한 지침서 및 수정안이 제안', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='만에서 운항하는 선박의 BWE + BWT 적용에 관한 지침서 및 수정안이 제안\n되었으나, 지침서 개발 전 고려되어야 하는 근본적인 요소들을 식별하였고, 이\n를 고려한 논의 및 제안문서 제출을 회원국들에게 요청한바 있다.\n근본적인 요소들에는 평형수처리설비 운전 불가 요건(수질인자, 상황, 시기\n등), 배출기준(D-2) 만족 여부, BWMS 우회운전 조건(비상상황 등), BWE +\nBWT 수행가능 구역 지정 등이 제시되었다.\nMEPC 78차에서는 수질 악조건 항만에서 운항하는 선박의 BWE + BWT 처리', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='MEPC 78차에서는 수질 악조건 항만에서 운항하는 선박의 BWE + BWT 처리\n지침 개발 및 방안 마련을 위한 논의를 지속키로 하였으며 MEPC 79차에서는\n우리나라와 중국과의 공동제출 의제문서를 기초로 하여 수질악조건 항만에서\n평형수의 교환 및 처리 방법 적용에 관한 근본적인 요소에 관한 검토를 완료\n했고, 평형수 작업반 검토 내용을 반영한 구체적인 지침서를 제출해 줄 것을\n요청하였다.\nMEPC 80차에서는 회기 중 선박평형수에 대한 작업반을 개설하여 논의를 진', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='요청하였다.\nMEPC 80차에서는 회기 중 선박평형수에 대한 작업반을 개설하여 논의를 진\n행하였으며, 작업반 주요 논의 사항 및 결과는 다음과 같다.\n경험축적기 동안 BWM 협약에 따른 항만국 통제활동을 독려키로 하였고, 수질\n악조건 항만(PCWQ)에서 운항하는 선박에 대한 BWM 협약 적용에 관한 지침\n서의 논의를 시작하여 지침서 작성에 대한 건, 사전 bypass에 대한 논의, 선\n원 친숙화 논의, 이해당사자의 정의 및 협약검토계획서 최종화를 위한 논의 진\n행하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='원 친숙화 논의, 이해당사자의 정의 및 협약검토계획서 최종화를 위한 논의 진\n행하였다.\n그러나, 도전적인 수질에서 운영되는 선박에 대한 BWM 협약의 적용에 관하여\n상호간 장시간의 작업을 통해 준비된 초안을 검토하였으나 광범위한 장시간의\n토론에도 불구하고, 그룹은 지침 초안에 대한 최종안 마련에 실패하였다. 일부\n대표단들이 다음 세션에서 이를 완료하기 위해 세션간 협력 의향을 가지고 있\n다는 점을 언급하였고 MEPC 81차 리뷰그룹 등을 통한 논의를 지속해 나갈\n예정이다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='다는 점을 언급하였고 MEPC 81차 리뷰그룹 등을 통한 논의를 지속해 나갈\n예정이다.\n6. 특별해역, 배출통제해역 및 특별민감해역의 식별\n홍해는 1973년 특별해역으로 채택 1983년 및 1988년에 발표되었고, 아덴만은\n1987년 특별해역으로 채택되어 1989년 발효된 바 있다. MARPOL 협약에 따\n라 RSGA(Red Sea and Gulf of Aden region) 국가들은 육상 수용시설을 충\n분히 확보하고 그 조치사항을 기구에 통보하도록 규정되어 있다.\n이에 따라 RSGA 국가들은 육상 수용시설을 충분히 확보했다고 주장하며 제\n15규칙(400GT 이상 선박 유성혼합물을 기름필터링장치를 통해 배출) 및 제34', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='15규칙(400GT 이상 선박 유성혼합물을 기름필터링장치를 통해 배출) 및 제34\n규칙(유탱커의 특별해역내에서의 기름 또는 유성혼합물을 바다로의 배출 금지)\n에 대한 효력 발생일에 대한 논의를 개시할 것을 제안하였다.\n또한, MARPOL 부속서 5 제6규칙(음식쓰레기 배출을 육지로부터 12해리 이상\n이격하여 배출, 25mm mesh 통과) 요건의 효력 발생일에 대한 논의 또한 진\n행할 것을 요청하였다.\n이에 따라 육상수용시설 확보에 대한 정보공유 및 서술한 MARPOL Annex I\n제15규칙, 제34규칙, Annex V 제6규칙의 효력 발생일 제안에 대한 논의가\n이뤄졌다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='제15규칙, 제34규칙, Annex V 제6규칙의 효력 발생일 제안에 대한 논의가\n이뤄졌다.\nMEPC 80차에 설립된 PSSA 논의를 위한 기술작업반에 NCSR 10(MEPC\n80/WP.8)의 관련 결과를 검토 및 북서 지중해해역을 PSSA로 지정하기 위한\nMEPC 결의안을 준비하고, 홍해 및 아덴만의 특별해역에 대한 MARPOL\nAnnex I, V의 규정 효력 발생일을 지정하기 위한 MEPC 결의서를 준비 요청\n하였다.\n기술작업반을 통해 준비된 결의서를 MEPC는 별도 이견 없이 승인하였고, 이\n에 따라 두 결의안의 효력 발생일은 2025년 1월 1일로 결정되었다.\n[IMO 관련 협의 사항]\n1. 벌크선 의제문서 제출 관련', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='[IMO 관련 협의 사항]\n1. 벌크선 의제문서 제출 관련\n벌크선 의제문서 제출 건(항만대기 및 선형별 유불리 사항 식별 및 조치) 관련\n하여 KMC 및 팬오션과의 현장 협의를 진행하였다. 이 자리에서 벌크선에 대\n한 CII 산정에 있어서의 불합리성 해소를 위한 의제문서 제출 등에 대한 내용\n에 대한 논의가 진행되었고, 400k 급 대형벌크선에 대한 CII 계산 문제점이\n식별되어 국내 대형 벌크선사 협의 및 관련 대응 방안을 논의해 나갈 계획이\n다. 이를 통해 2023년 중 의제문서 작성을 위한 협의 및 데이터 취합을 통한', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'}),
#  Document(page_content='다. 이를 통해 2023년 중 의제문서 작성을 위한 협의 및 데이터 취합을 통한\n의제문서 초안을 작성하고 2024년 초 의제문서를 최종 마무리하여 MEPC 81\n차에 제출할 계획이다.\n2. 중장기 조치에 대한 의견 수렴\n중장기 조치 도입에 관한 사항 중 IMO 와 EU 의 규제 중복사항 (FuelEU\nMaritime 및 GFS) 등에 대한 탄소세 부과 시 이중 부담이 있을 수 있는 점에\n대한 의견조회 결과 FuelEU Maritime 규정에 IMO 등 상위 규제가 적용될\n경우 재검토(Review) 규정이 명시되어 있어 중복규제 등을 조정할 수 있을 것\n이라는 사항을 확인하였다.', metadata={'source': '../files/MEPC 80차 결과 보고서_송부 20230713_한국해운협회 해무팀.pdf'})]
